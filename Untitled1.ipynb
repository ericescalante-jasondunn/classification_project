# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

from pydataset import data

# Logistc Regression
from sklearn.linear_model import LogisticRegression

# Decision Tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# KNN
from sklearn.neighbors import KNeighborsClassifier

# Random Forest
from sklearn.ensemble import RandomForestClassifier

# All modeling
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder


# %matplotlib inline
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns

import env

# %%
def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

def get_telco_data():
    '''gets all telco data from sql dbase'''
    return pd.read_sql('\
    SELECT c.*, ct.contract_type, ist.internet_service_type, pt.payment_type FROM customers c\
    JOIN contract_types ct ON c.contract_type_id = ct.contract_type_id\
    JOIN internet_service_types ist ON c.internet_service_type_id = ist.internet_service_type_id\
    JOIN payment_types pt ON c.payment_type_id = pt.payment_type_id',\
    get_connection('telco_churn'))

# %%
df = get_telco_data()
df.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0003-MKNFE    Male               0      No         No       9
# 1  0013-MHZWF  Female               0      No        Yes       9
# 2  0015-UOCOJ  Female               1      No         No       7
# 3  0023-HGHWL    Male               1      No         No       1
# 4  0032-PGELS  Female               0     Yes        Yes       1
#
#   phone_service    multiple_lines  internet_service_type_id online_security  \
# 0           Yes               Yes                         1              No
# 1           Yes                No                         1              No
# 2           Yes                No                         1             Yes
# 3            No  No phone service                         1              No
# 4            No  No phone service                         1             Yes
#
#              ...             streaming_movies contract_type_id  \
# ...

# %%
df[['tenure', 'monthly_charges']] = df[['tenure', 'monthly_charges']].astype(float)

# %%
df['total_tenure_charge'] = df['tenure']*df['monthly_charges']

# %%
sns.pairplot(df, hue='churn')

# %% [markdown]
# **Internet Service Type Breakdown**

# %%
df.internet_service_type_id.value_counts(sort=False)
# Out:
# 1    2421
# 2    3096
# 3    1526
# Name: internet_service_type_id, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="internet_service_type_id", y="tenure", hue="churn", data=df, palette="Set2")

# %% [markdown]
# **Internet Service Type Options**
# 1. DSL
# 2. Fiber optic
# 3. None
#
# **Interesting Takeaways**
# 1. DSL customers churn in the beginning of their tenure with Telco
# 2. A ton of Fiber optic customers churn during the rookie year of their tenureship
# 3. Not really a pattern of churn of customers without an internet service with Telco

# %% [markdown]
# **Contract Type Breakdown**

# %%
df.contract_type_id.value_counts(sort=False)
# Out:
# 1    3875
# 2    1473
# 3    1695
# Name: contract_type_id, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="contract_type_id", y="tenure", hue="churn", data=df, palette="Set2")

# %% [markdown]
# **Contract Type Options**
# 1. Month-to-month
# 2. One year
# 3. Two year
#
# **Interesting Takeaways**
# 1. The mean tenure of churn'd customers is significantly lower with the month to month payment plan
# 2. The mean tenure of churn'd customers is slightly higher with the 1 year contract plan
# 3. the mean of the 2 year churn'd/not churn customers is pretty much even

# %% [markdown]
# **Payment Type Breakdown**

# %%
df.payment_type_id.value_counts()
# Out:
# 1    2365
# 2    1612
# 3    1544
# 4    1522
# Name: payment_type_id, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.pointplot(x="payment_type_id", y="monthly_charges", hue="churn", data=df, palette="Set2")

# %% [markdown]
# **Payment Type Options**
# 1. Electronic Check
# 2. Mailed Check
# 3. Bank Transfer (automatic)
# 4. Credit Card (automatic)
#
# **Interesting Takeaways**
# 1. Customers that use the mailed check payment method AND have the highes monthly charges are staying with Telco
# 2. Customers that use the mailed check payment method have longest tenure are also staying
# 3. We will look at some ttests later on down the road
#
# **Questions for later**
# 1. Why is the bill so much lower for the customers that mail in their check?

# %%
df.tenure.value_counts(bins=6, sort=False)
# Out:
# (-0.073, 12.0]    2186
# (12.0, 24.0]      1024
# (24.0, 36.0]       832
# (36.0, 48.0]       762
# (48.0, 60.0]       832
# (60.0, 72.0]      1407
# Name: tenure, dtype: int64

# %%
f, ax = plt.subplots(figsize=(7, 6))
sns.pointplot(x="tenure", y="monthly_charges", hue="churn", data=df, palette="Set2")
ax.set_xscale("linear")
